# %% [markdown]
# <a href="https://colab.research.google.com/github/Kvaibhav1997/Cancer-Prediction/blob/main/Kumar_Vaibhav_Assignment_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.naive_bayes import GaussianNB
import numpy as np
import seaborn as sns
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import plotly.express as px
from sklearn.metrics import confusion_matrix  
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

# %%
df=pd.read_csv('data.csv')
df.head()
# Out:
#          id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0    842302         M  ...                  0.11890          NaN
# 1    842517         M  ...                  0.08902          NaN
# 2  84300903         M  ...                  0.08758          NaN
# 3  84348301         M  ...                  0.17300          NaN
# 4  84358402         M  ...                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
df.shape
# Out:
# (569, 33)

# %%
df.drop(['id','Unnamed: 32'], axis=1, inplace=True)
df.head()
# Out:
#   diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# 0         M        17.99  ...          0.4601                  0.11890
# 1         M        20.57  ...          0.2750                  0.08902
# 2         M        19.69  ...          0.3613                  0.08758
# 3         M        11.42  ...          0.6638                  0.17300
# 4         M        20.29  ...          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
fig = px.scatter(df, x="texture_mean", y="radius_mean", color="diagnosis", title="A Plotly Express Figure")


# If you print the figure, you'll see that it's just a regular figure with data and layout
# print(fig)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a81b240e-79be-4998-9fbe-c33dfc74bbe4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a81b240e-79be-4998-9fbe-c33dfc74bbe4")) {
#                     Plotly.newPlot(
#                         'a81b240e-79be-4998-9fbe-c33dfc74bbe4',
# ...

# %%
le=LabelEncoder()
df['diagnosis']=le.fit_transform(df['diagnosis'])
df['diagnosis'].value_counts()
# Out:
# 0    357
# 1    212
# Name: diagnosis, dtype: int64

# %%
data=df.corr()
plt.figure(figsize=(19,12))
sns.heatmap(data,annot=True)
plt.show()

# %%
df.columns
col=['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
       'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
       'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
       'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
       'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
       'fractal_dimension_se', 'radius_worst', 'texture_worst',
       'perimeter_worst', 'area_worst', 'smoothness_worst',
       'compactness_worst', 'concavity_worst', 'concave points_worst',
       'symmetry_worst', 'fractal_dimension_worst']

# %%
mmx=MinMaxScaler()
mmx.fit(df)
new_df=mmx.transform(df)

# %%
new_df=pd.DataFrame(new_df, columns=col)
new_df['diagnosis'] = new_df['diagnosis'].astype(int)
new_df
# Out:
#      diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# 0            1     0.521037  ...        0.598462                 0.418864
# 1            1     0.643144  ...        0.233590                 0.222878
# 2            1     0.601496  ...        0.403706                 0.213433
# 3            1     0.210090  ...        1.000000                 0.773711
# 4            1     0.629893  ...        0.157500                 0.142595
# ..         ...          ...  ...             ...                      ...
# 564          1     0.690000  ...        0.097575                 0.105667
# 565          1     0.622320  ...        0.198502                 0.074315
# 566          1     0.455251  ...        0.128721                 0.151909
# 567          1     0.644564  ...        0.497142                 0.452315
# 568          0     0.036869  ...        0.257441                 0.100682
#
# [569 rows x 31 columns]

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    int64
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...

# %%
y=new_df.iloc[:,:1]
x=new_df.iloc[:,1:]
x
# Out:
#      radius_mean  texture_mean  ...  symmetry_worst  fractal_dimension_worst
# 0       0.521037      0.022658  ...        0.598462                 0.418864
# 1       0.643144      0.272574  ...        0.233590                 0.222878
# 2       0.601496      0.390260  ...        0.403706                 0.213433
# 3       0.210090      0.360839  ...        1.000000                 0.773711
# 4       0.629893      0.156578  ...        0.157500                 0.142595
# ..           ...           ...  ...             ...                      ...
# 564     0.690000      0.428813  ...        0.097575                 0.105667
# 565     0.622320      0.626987  ...        0.198502                 0.074315
# 566     0.455251      0.621238  ...        0.128721                 0.151909
# 567     0.644564      0.663510  ...        0.497142                 0.452315
# 568     0.036869      0.501522  ...        0.257441                 0.100682
#
# [569 rows x 30 columns]

# %%
print(x.shape)
print(y.shape)
# Out:
# (569, 30)
# (569, 1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.35, random_state = 42)

# %%
nb = GaussianNB()
nb.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:985: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# GaussianNB()

# %%
print("Naive Bayes score: ",nb.score(x_test, y_test))
# Out:
# Naive Bayes score:  0.94

# %%
y_pred = nb.predict(x_test)

# %%
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95       129
#            1       0.92      0.92      0.92        71
#
#     accuracy                           0.94       200
#    macro avg       0.93      0.93      0.93       200
# weighted avg       0.94      0.94      0.94       200

# %%
print("The accuracy of the model is:",accuracy_score(y_pred, y_test)*100,"%")
# Out:
# The accuracy of the model is: 94.0 %

# %%
cm = confusion_matrix(y_test, y_pred) 
cm
# Out:
# array([[123,   6],
#        [  6,  65]])
